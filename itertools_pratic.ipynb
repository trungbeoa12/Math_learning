# %%
from itertools import combinations, accumulate

items = [1, 2, 3]

for c in combinations(items, 2):
    print(c)
# Out:
# (1, 2)
# (1, 3)
# (2, 3)

# %%
from itertools import combinations

rows = combinations(range(3), 2)

for r in rows:
    print(r)
# Out:
# (0, 1)
# (0, 2)
# (1, 2)

# %%
from itertools import permutations

items = [1, 2, 3,4]

for p in permutations(items):
    print(p)
# Out:
# (1, 2, 3, 4)
# (1, 2, 4, 3)
# (1, 3, 2, 4)
# (1, 3, 4, 2)
# (1, 4, 2, 3)
# (1, 4, 3, 2)
# (2, 1, 3, 4)
# (2, 1, 4, 3)
# (2, 3, 1, 4)
# (2, 3, 4, 1)
# (2, 4, 1, 3)
# (2, 4, 3, 1)
# (3, 1, 2, 4)
# (3, 1, 4, 2)
# (3, 2, 1, 4)
# (3, 2, 4, 1)
# (3, 4, 1, 2)
# (3, 4, 2, 1)
# (4, 1, 2, 3)
# (4, 1, 3, 2)
# (4, 2, 1, 3)
# (4, 2, 3, 1)
# (4, 3, 1, 2)
# (4, 3, 2, 1)

# %%
for p in permutations(items, 2):
    print(p)
# Out:
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 1)
# (2, 3)
# (2, 4)
# (3, 1)
# (3, 2)
# (3, 4)
# (4, 1)
# (4, 2)
# (4, 3)
